# %%
import pandas as pd

# %%
df = pd.read_csv('./corpus-metadata-fixed.tsv',sep='\t',index_col=0)

# %%
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#             authors                                          genres  \
# 0    ['николай ii']                                    ['манифест']
# 1    ['николай ii']                                    ['манифест']
# 2    ['николай ii']                                    ['манифест']
# 3    ['николай ii']                                    ['манифест']
# 4    ['николай ii']                                    ['манифест']
# ..              ...                                             ...
# 357       ['путин']                     ['выступление', 'послание']
# 358       ['путин']  ['выступление', 'обращение к гражданам', 'тв']
# 359       ['путин']  ['выступление', 'обращение к гражданам', 'тв']
# 360       ['путин']  ['выступление', 'обращение к гражданам', 'тв']
# 361       ['путин']                                 ['выступление']
#
#                                                  names  \
# 0                          ['о восшествии на престол']
# 1                                      ['коронование']
# 2                    ['законы княжества финляндского']
# 3        ['усовершенствование государственной власти']
# 4       ['об открытии военных действий против японии']
# ..                                                 ...
# 357                 ['послание федеральному собранию']
# 358                          ['обращение к гражданам']
# 359                          ['обращение к гражданам']
# 360                          ['обращение к гражданам']
# 361  ['выступление на церемонии вступления в должно...
#
#                                             topics  multiple_authors  \
# 0                      ['о восшествии на престол']             False
# 1                                  ['коронование']             False
# 2                ['законы княжества финляндского']             False
# 3    ['усовершенствование государственной власти']             False
# 4                   ['русско японская война 1904']             False
# ..                                             ...               ...
# 357             ['послание федеральному собранию']             False
# 358                                ['выборы 2024']             False
# 359               ['выборы 2024', 'итоги выборов']             False
# 360                           ['теракт в крокусе']             False
# 361                                ['инаугурация']             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False             True
# ..                ...              ...
# 357             False            False
# 358             False             True
# 359             False             True
# 360             False             True
# 361             False             True
#
# [362 rows x 12 columns]

# %%
df.iloc[0]['authors']
# Out:
# "['николай ii']"

# %%
import ast

# %%
def list_in_string_to_list(list_wrapped_in_string):
    return ast.literal_eval(list_wrapped_in_string)

# %%
type(df['authors'].apply(list_in_string_to_list).iloc[0])
# Out:
# list

# %%
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#             authors                                          genres  \
# 0    ['николай ii']                                    ['манифест']
# 1    ['николай ii']                                    ['манифест']
# 2    ['николай ii']                                    ['манифест']
# 3    ['николай ii']                                    ['манифест']
# 4    ['николай ii']                                    ['манифест']
# ..              ...                                             ...
# 357       ['путин']                     ['выступление', 'послание']
# 358       ['путин']  ['выступление', 'обращение к гражданам', 'тв']
# 359       ['путин']  ['выступление', 'обращение к гражданам', 'тв']
# 360       ['путин']  ['выступление', 'обращение к гражданам', 'тв']
# 361       ['путин']                                 ['выступление']
#
#                                                  names  \
# 0                          ['о восшествии на престол']
# 1                                      ['коронование']
# 2                    ['законы княжества финляндского']
# 3        ['усовершенствование государственной власти']
# 4       ['об открытии военных действий против японии']
# ..                                                 ...
# 357                 ['послание федеральному собранию']
# 358                          ['обращение к гражданам']
# 359                          ['обращение к гражданам']
# 360                          ['обращение к гражданам']
# 361  ['выступление на церемонии вступления в должно...
#
#                                             topics  multiple_authors  \
# 0                      ['о восшествии на престол']             False
# 1                                  ['коронование']             False
# 2                ['законы княжества финляндского']             False
# 3    ['усовершенствование государственной власти']             False
# 4                   ['русско японская война 1904']             False
# ..                                             ...               ...
# 357             ['послание федеральному собранию']             False
# 358                                ['выборы 2024']             False
# 359               ['выборы 2024', 'итоги выборов']             False
# 360                           ['теракт в крокусе']             False
# 361                                ['инаугурация']             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False             True
# ..                ...              ...
# 357             False            False
# 358             False             True
# 359             False             True
# 360             False             True
# 361             False             True
#
# [362 rows x 12 columns]

# %%
df['authors'] = df['authors'].apply(list_in_string_to_list)
df['genres'] = df['genres'].apply(list_in_string_to_list)
df['names'] = df['names'].apply(list_in_string_to_list)
df['topics'] = df['topics'].apply(list_in_string_to_list)
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False             True
# ..                ...              ...
# 357             False            False
# 358             False             True
# 359             False             True
# 360             False             True
# 361             False             True
#
# [362 rows x 12 columns]

# %%
type(df['regular_occasion'].iloc[0])
# Out:
# numpy.bool_

# %%
def bool_str_to_int_str(bool_val):
    return str(bool_val.astype(int))

# %%
df['pattern'] = df['multiple_authors'].astype(int).astype(str) \
+df['leader_in_authors'].astype(int).astype(str)\
+df['is_written_text'].astype(int).astype(str)\
+df['addressed_to_people'].astype(int).astype(str)\
+df['regular_occasion'].astype(int).astype(str)\
+df['has_major_topic'].astype(int).astype(str)
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern
# 0               False            False  011100
# 1               False            False  011100
# 2               False            False  011100
# 3               False            False  011100
# 4               False             True  011101
# ..                ...              ...     ...
# 357             False            False  010000
# 358             False             True  010101
# 359             False             True  010101
# 360             False             True  010101
# 361             False             True  010001
#
# [362 rows x 13 columns]

# %%
df.groupby(by=['pattern']).count().sort_values(by=['filename'], ascending=False)['filename']
# Out:
# pattern
# 101000    73
# 010000    36
# 011001    31
# 101001    31
# 010101    27
# 010011    24
# 010001    19
# 100000    18
# 111000    17
# 011000    16
# 011100     9
# 011101     9
# 111001     8
# 101010     6
# 101100     6
# 000011     5
# 111010     4
# 101101     4
# 111100     3
# 111101     3
# 000001     3
# 101011     3
# 010100     3
# 100001     1
# 010010     1
# 001001     1
# 111110     1
# Name: filename, dtype: int64

# %%
df['pattern'] = df['multiple_authors'].astype(int).astype(str) \
+df['leader_in_authors'].astype(int).astype(str)\
+df['is_written_text'].astype(int).astype(str)\
+df['addressed_to_people'].astype(int).astype(str)\
+df['regular_occasion'].astype(int).astype(str)\
# +df['has_major_topic'].astype(int).astype(str)
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern
# 0               False            False   01110
# 1               False            False   01110
# 2               False            False   01110
# 3               False            False   01110
# 4               False             True   01110
# ..                ...              ...     ...
# 357             False            False   01000
# 358             False             True   01010
# 359             False             True   01010
# 360             False             True   01010
# 361             False             True   01000
#
# [362 rows x 13 columns]

# %%
df.groupby(by=['pattern']).count().sort_values(by=['filename'], ascending=False)['filename']
# Out:
# pattern
# 10100    104
# 01000     55
# 01100     47
# 01010     30
# 01001     25
# 11100     25
# 10000     19
# 01110     18
# 10110     10
# 10101      9
# 11110      6
# 00001      5
# 11101      4
# 00000      3
# 00100      1
# 11111      1
# Name: filename, dtype: int64

# %%
top_10_patterns = df.groupby(by=['pattern']).count().sort_values(by=['filename'], ascending=False)['filename'].index.to_list()[:10]
top_10_patterns
# Out:
# ['10100',
#  '01000',
#  '01100',
#  '01010',
#  '01001',
#  '11100',
#  '10000',
#  '01110',
#  '10110',
#  '10101']

# %%
top_5_patterns = df.groupby(by=['pattern']).count().sort_values(by=['filename'], ascending=False)['filename'].index.to_list()[:5]
top_5_patterns
# Out:
# ['10100', '01000', '01100', '01010', '01001']

# %%
df['year'] = df['date'].apply(lambda x: int(x.split('.')[0]))
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year
# 0               False            False   01110  1894
# 1               False            False   01110  1896
# 2               False            False   01110  1899
# 3               False            False   01110  1903
# 4               False             True   01110  1904
# ..                ...              ...     ...   ...
# 357             False            False   01000  2024
# 358             False             True   01010  2024
# 359             False             True   01010  2024
# 360             False             True   01010  2024
# 361             False             True   01000  2024
#
# [362 rows x 14 columns]

# %%
df.groupby('year').count()['filename'].plot.line()
# Out:
# <Axes: xlabel='year'>

# %%
df.groupby('year').count()['filename'].mean()
# Out:
# 4.469135802469136

# %%
df.groupby('year').count()['filename'].sort_values(ascending=False)
# Out:
# year
# 1918    58
# 1917    39
# 1988    10
# 2020    10
# 1922    10
#         ..
# 1896     1
# 1975     1
# 1964     1
# 2004     1
# 1894     1
# Name: filename, Length: 81, dtype: int64

# %%
df.groupby(by=['year','pattern']).count()

grouped_by_year_by_pattern = df.groupby(by=['year','pattern']).count()
grouped_by_year_by_pattern.pivot_table(values="filename",index="year",columns="pattern").fillna(0).plot()
# Out:
# <Axes: xlabel='year'>

# %%
grouped_by_year_by_pattern
# Out:
#               filename  date  authors  genres  names  topics  \
# year pattern
# 1894 01110           1     1        1       1      1       1
# 1896 01110           1     1        1       1      1       1
# 1899 01110           1     1        1       1      1       1
# 1903 01110           1     1        1       1      1       1
# 1904 01100           1     1        1       1      1       1
# ...                ...   ...      ...     ...    ...     ...
# 2023 01000           1     1        1       1      1       1
#      01010           2     2        2       2      2       2
#      01100           1     1        1       1      1       1
# 2024 01000           2     2        2       2      2       2
#      01010           3     3        3       3      3       3
#
#               multiple_authors  leader_in_authors  is_written_text  \
# year pattern
# 1894 01110                   1                  1                1
# 1896 01110                   1                  1                1
# 1899 01110                   1                  1                1
# 1903 01110                   1                  1                1
# 1904 01100                   1                  1                1
# ...                        ...                ...              ...
# 2023 01000                   1                  1                1
#      01010                   2                  2                2
#      01100                   1                  1                1
# 2024 01000                   2                  2                2
#      01010                   3                  3                3
#
#               addressed_to_people  regular_occasion  has_major_topic
# year pattern
# 1894 01110                      1                 1                1
# 1896 01110                      1                 1                1
# 1899 01110                      1                 1                1
# 1903 01110                      1                 1                1
# 1904 01100                      1                 1                1
# ...                           ...               ...              ...
# 2023 01000                      1                 1                1
#      01010                      2                 2                2
#      01100                      1                 1                1
# 2024 01000                      2                 2                2
#      01010                      3                 3                3
#
# [177 rows x 12 columns]

# %%
df.groupby(by=['pattern']).count().sort_values(by=['filename'], ascending=False)
# Out:
#          filename  date  authors  genres  names  topics  multiple_authors  \
# pattern
# 10100         104   104      104     104    104     104               104
# 01000          55    55       55      55     55      55                55
# 01100          47    47       47      47     47      47                47
# 01010          30    30       30      30     30      30                30
# 01001          25    25       25      25     25      25                25
# 11100          25    25       25      25     25      25                25
# 10000          19    19       19      19     19      19                19
# 01110          18    18       18      18     18      18                18
# 10110          10    10       10      10     10      10                10
# 10101           9     9        9       9      9       9                 9
# 11110           6     6        6       6      6       6                 6
# 00001           5     5        5       5      5       5                 5
# 11101           4     4        4       4      4       4                 4
# 00000           3     3        3       3      3       3                 3
# 00100           1     1        1       1      1       1                 1
# 11111           1     1        1       1      1       1                 1
#
#          leader_in_authors  is_written_text  addressed_to_people  \
# pattern
# 10100                  104              104                  104
# 01000                   55               55                   55
# 01100                   47               47                   47
# 01010                   30               30                   30
# 01001                   25               25                   25
# 11100                   25               25                   25
# 10000                   19               19                   19
# 01110                   18               18                   18
# 10110                   10               10                   10
# 10101                    9                9                    9
# 11110                    6                6                    6
# 00001                    5                5                    5
# 11101                    4                4                    4
# 00000                    3                3                    3
# 00100                    1                1                    1
# 11111                    1                1                    1
#
#          regular_occasion  has_major_topic  year
# pattern
# 10100                 104              104   104
# 01000                  55               55    55
# 01100                  47               47    47
# 01010                  30               30    30
# 01001                  25               25    25
# 11100                  25               25    25
# 10000                  19               19    19
# 01110                  18               18    18
# 10110                  10               10    10
# 10101                   9                9     9
# 11110                   6                6     6
# 00001                   5                5     5
# 11101                   4                4     4
# 00000                   3                3     3
# 00100                   1                1     1
# 11111                   1                1     1

# %%
df[df['year']>1960][df['year']<1990].groupby(by=['year','pattern']).count()

grouped_by_year_by_pattern = df[df['year']>1960][df['year']<1990].groupby(by=['year','pattern']).count()
grouped_by_year_by_pattern.pivot_table(values="filename",index="year",columns="pattern").fillna(0).plot()
# Out:
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/506744833.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['year']>1960][df['year']<1990].groupby(by=['year','pattern']).count()
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/506744833.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   grouped_by_year_by_pattern = df[df['year']>1960][df['year']<1990].groupby(by=['year','pattern']).count()
# <Axes: xlabel='year'>

# %%
grouped_by_year_by_pattern.pivot_table(values="filename",index="year",columns="pattern")
# Out:
# pattern  01000  01001  10000  10100  10101  11100
# year
# 1961       NaN    1.0    NaN    2.0    NaN    NaN
# 1964       NaN    NaN    NaN    1.0    NaN    NaN
# 1966       NaN    2.0    1.0    1.0    NaN    NaN
# 1969       1.0    NaN    NaN    NaN    NaN    NaN
# 1971       NaN    2.0    1.0    1.0    NaN    NaN
# 1975       NaN    NaN    NaN    NaN    1.0    NaN
# 1976       NaN    1.0    NaN    1.0    NaN    NaN
# 1977       NaN    NaN    NaN    1.0    NaN    NaN
# 1978       NaN    NaN    NaN    NaN    NaN    1.0
# 1981       NaN    1.0    NaN    NaN    1.0    NaN
# 1986       NaN    NaN    5.0    4.0    NaN    NaN
# 1988       1.0    NaN    4.0    4.0    1.0    NaN
# 1989       NaN    2.0    NaN    NaN    NaN    NaN

# %%
type(df['pattern'].iloc[0])
# Out:
# str

# %%
df[
    df['pattern'].isin(top_5_patterns)
].groupby(by=['year','pattern']).count()
# Out:
#               filename  date  authors  genres  names  topics  \
# year pattern
# 1904 01100           1     1        1       1      1       1
# 1917 01100           2     2        2       2      2       2
#      10100          20    20       20      20     20      20
# 1918 01001           2     2        2       2      2       2
#      01100           1     1        1       1      1       1
# ...                ...   ...      ...     ...    ...     ...
# 2023 01000           1     1        1       1      1       1
#      01010           2     2        2       2      2       2
#      01100           1     1        1       1      1       1
# 2024 01000           2     2        2       2      2       2
#      01010           3     3        3       3      3       3
#
#               multiple_authors  leader_in_authors  is_written_text  \
# year pattern
# 1904 01100                   1                  1                1
# 1917 01100                   2                  2                2
#      10100                  20                 20               20
# 1918 01001                   2                  2                2
#      01100                   1                  1                1
# ...                        ...                ...              ...
# 2023 01000                   1                  1                1
#      01010                   2                  2                2
#      01100                   1                  1                1
# 2024 01000                   2                  2                2
#      01010                   3                  3                3
#
#               addressed_to_people  regular_occasion  has_major_topic
# year pattern
# 1904 01100                      1                 1                1
# 1917 01100                      2                 2                2
#      10100                     20                20               20
# 1918 01001                      2                 2                2
#      01100                      1                 1                1
# ...                           ...               ...              ...
# 2023 01000                      1                 1                1
#      01010                      2                 2                2
#      01100                      1                 1                1
# 2024 01000                      2                 2                2
#      01010                      3                 3                3
#
# [126 rows x 12 columns]

# %%
count_by_top_5_patters_by_year = df[
    df['pattern'].isin(top_5_patterns)
].groupby(by=['year','pattern']).count()

grouped_by_year_by_pattern = count_by_top_5_patters_by_year
grouped_by_year_by_pattern.pivot_table(values="filename",index="year",columns="pattern").fillna(0).plot()
# Out:
# <Axes: xlabel='year'>

# %%
count_by_top_10_patters_by_year = df[
    df['pattern'].isin(top_10_patterns)
].groupby(by=['year','pattern']).count()

grouped_by_year_by_pattern = count_by_top_10_patters_by_year
grouped_by_year_by_pattern.pivot_table(values="filename",index="year",columns="pattern").plot()
# Out:
# <Axes: xlabel='year'>

# %%
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year
# 0               False            False   01110  1894
# 1               False            False   01110  1896
# 2               False            False   01110  1899
# 3               False            False   01110  1903
# 4               False             True   01110  1904
# ..                ...              ...     ...   ...
# 357             False            False   01000  2024
# 358             False             True   01010  2024
# 359             False             True   01010  2024
# 360             False             True   01010  2024
# 361             False             True   01000  2024
#
# [362 rows x 14 columns]

# %%
def if_elements_in_column_then_feature_is(column, list_of_elements=[], feature_is=True, otherwise=False):
    for column_elem in column:
        for list_elem in list_of_elements:
            if list_elem in column_elem:
                return feature_is 
    return otherwise

# %%
df['is_fragment'] = df['genres'].apply(if_elements_in_column_then_feature_is, list_of_elements=['фрагмент'])
df[
    df['is_fragment'] == True
   ]
# Out:
#                                               filename        date  \
# 70   1918.03.08_ленин ркпб 7_резолюция.фрагмент_о в...  1918.03.08
# 71   1918.03.08_ленин_выступление.фрагмент_вопрос о...  1918.03.08
# 111  1919.03.18_ленин_выступление.отчет.фрагмент_от...  1919.03.18
# 112  1919.03.18_ленин_выступление.фрагмент_о деятел...  1919.03.18
# 118  1921.03.05_ленин_выступление.отчет.фрагмент_по...  1921.03.05
# 120  1921.03.07_цк ркпб.ркпб 10_отчет.фрагмент_о де...  1921.03.07
# 124  1922.03.27_ленин_выступление.фрагмент.отчет_по...  1922.03.27
# 140  1923.04.19_зиновьев_выступление.отчет.доклад.ф...  1923.04.19
# 144  1924.04.16_калинин_выступление.доклад.фрагмент...  1924.04.16
# 145  1924.05.27_съезд ркпб 13_резолюция фрагмент_по...  1924.05.27
# 146  1924.05.29_крупская_выступление.фрагмент.докла...  1924.05.29
# 149  1924.05.31_съезд ркпб 13_постановление.фрагмен...  1924.05.31
# 150  1924.05.31_съезд ркпб 13_резолюция.фрагмент_о ...  1924.05.31
# 152  1925.04.29_партконференция 14_резолюция.фрагме...  1925.04.29
# 153  1925.12.23_съезд вкпб 14_резолюция.фрагмент_о ...  1925.12.23
# 157  1927.12.19_съезд вкпб 15_резолюция.фрагмент_о ...  1927.12.19
# 158  1927.12.19_съезд вкпб 15_резолюция.фрагмент_по...  1927.12.19
# 162  1930.07.13_съезд вкпб 16_резолюция.фрагмент_по...  1930.07.13
# 164  1930.12.21_цк вкпб.цкк вкпб_стенограмма.отчет....  1930.12.21
# 166  1934.01.31_бухарин_выступление.фрагмент_речь н...  1934.01.31
# 167  1934.02.10_съезд вкпб 17_резолюция.фрагмент_о ...  1934.02.10
# 168  1934.02.10_съезд вкпб 17_резолюция.фрагмент_па...  1934.02.10
# 204  1959.02.05_съезд кпсс 21_доклад.фрагмент_контр...  1959.02.05
# 205  1959.02.05_съезд кпсс 21_резолюция.фрагмент_по...  1959.02.05
# 210  1961.10.31_съезд кпсс 22_резолюция.фрагмент_по...  1961.10.31
# 220  1971.04.09_съезд кпсс 24_резолюция.фрагмент_по...  1971.04.09
#
#                   authors                                     genres  \
# 70         [ленин ркпб 7]                      [резолюция, фрагмент]
# 71                [ленин]                    [выступление, фрагмент]
# 111               [ленин]             [выступление, отчет, фрагмент]
# 112               [ленин]                    [выступление, фрагмент]
# 118               [ленин]             [выступление, отчет, фрагмент]
# 120    [цк ркпб, ркпб 10]                          [отчет, фрагмент]
# 124               [ленин]             [выступление, фрагмент, отчет]
# 140            [зиновьев]     [выступление, отчет, доклад, фрагмент]
# 144             [калинин]            [выступление, доклад, фрагмент]
# 145       [съезд ркпб 13]                       [резолюция фрагмент]
# 146            [крупская]            [выступление, фрагмент, доклад]
# 149       [съезд ркпб 13]                  [постановление, фрагмент]
# 150       [съезд ркпб 13]                      [резолюция, фрагмент]
# 152  [партконференция 14]                      [резолюция, фрагмент]
# 153       [съезд вкпб 14]                      [резолюция, фрагмент]
# 157       [съезд вкпб 15]                      [резолюция, фрагмент]
# 158       [съезд вкпб 15]                      [резолюция, фрагмент]
# 162       [съезд вкпб 16]                      [резолюция, фрагмент]
# 164   [цк вкпб, цкк вкпб]  [стенограмма, отчет, фрагмент, заседание]
# 166             [бухарин]                    [выступление, фрагмент]
# 167       [съезд вкпб 17]                      [резолюция, фрагмент]
# 168       [съезд вкпб 17]                      [резолюция, фрагмент]
# 204       [съезд кпсс 21]                         [доклад, фрагмент]
# 205       [съезд кпсс 21]                      [резолюция, фрагмент]
# 210       [съезд кпсс 22]                      [резолюция, фрагмент]
# 220       [съезд кпсс 24]                      [резолюция, фрагмент]
#
#                                                  names  \
# 70                      [о войне и мире, съезд ркпб 7]
# 71                           [вопрос о брестском мире]
# 111                                         [отчет цк]
# 112       [о деятельности федерации иностранных групп]
# 118                               [политический отчет]
# 120                            [о деятельности партии]
# 124                               [политический отчет]
# 140                            [политический отчет цк]
# 144                               [о работе в деревне]
# 145                                     [по отчету цк]
# 146                               [о работе в деревне]
# 149                          [о работе среди молодежи]
# 150                               [о работе в деревне]
# 152  [о возможности победы социализма в одной стран...
# 153                              [о работе профсоюзов]
# 157                               [о работе в деревне]
# 158                                     [по отчету цк]
# 162                                     [по отчету цк]
# 164  [прения по докладу куйбышева о народно хозяйст...
# 166                                [речь на 17 съезде]
# 167  [о втором пятилетнем плане развития народного ...
# 168  [партийное и советское строительство, организа...
# 204            [контрольные цифры народного хозяйства]
# 205  [по докладу контрольные цифры народного хозяйс...
# 210                                     [по отчету цк]
# 220                             [по отчетному докладу]
#
#                                                 topics  multiple_authors  \
# 70                      [о войне и мире, съезд ркпб 7]              True
# 71      [съезд ркпб 7, брестский мир, 1 мировая война]             False
# 111                                     [съезд ркпб 8]             False
# 112                                     [съезд ркпб 8]             False
# 118                                    [съезд ркпб 10]             False
# 120                            [о деятельности партии]              True
# 124                                    [съезд ркпб 11]             False
# 140                                    [съезд ркпб 12]             False
# 144                                    [съезд ркпб 13]             False
# 145                                     [по отчету цк]              True
# 146                                    [съезд ркпб 13]             False
# 149                          [о работе среди молодежи]              True
# 150                               [о работе в деревне]              True
# 152  [о возможности победы социализма в одной стран...              True
# 153                              [о работе профсоюзов]              True
# 157                               [о работе в деревне]              True
# 158                                     [по отчету цк]              True
# 162                                     [по отчету цк]              True
# 164                        [отстранение рыкова из снк]              True
# 166                                [германия и япония]             False
# 167                                      [2 пятилетка]              True
# 168  [партийное и советское строительство, организа...              True
# 204            [контрольные цифры народного хозяйства]              True
# 205  [по докладу контрольные цифры народного хозяйс...              True
# 210                                     [по отчету цк]              True
# 220                             [по отчетному докладу]              True
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 70               False             True                False
# 71                True            False                False
# 111               True            False                False
# 112               True            False                False
# 118               True            False                False
# 120              False            False                False
# 124               True            False                False
# 140              False            False                False
# 144              False            False                False
# 145              False             True                False
# 146              False            False                False
# 149              False             True                False
# 150              False             True                False
# 152              False             True                False
# 153              False             True                False
# 157              False             True                False
# 158              False             True                False
# 162              False             True                False
# 164              False            False                False
# 166              False            False                False
# 167              False             True                False
# 168              False             True                False
# 204              False            False                False
# 205              False             True                False
# 210              False             True                False
# 220              False             True                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment
# 70               True            False   10101  1918         True
# 71               True             True   01001  1918         True
# 111              True             True   01001  1919         True
# 112              True             True   01001  1919         True
# 118              True             True   01001  1921         True
# 120             False            False   10000  1921         True
# 124              True             True   01001  1922         True
# 140              True             True   00001  1923         True
# 144              True             True   00001  1924         True
# 145             False            False   10100  1924         True
# 146              True             True   00001  1924         True
# 149             False            False   10100  1924         True
# 150             False            False   10100  1924         True
# 152             False            False   10100  1925         True
# 153             False            False   10100  1925         True
# 157             False            False   10100  1927         True
# 158             False            False   10100  1927         True
# 162             False            False   10100  1930         True
# 164             False             True   10000  1930         True
# 166             False             True   00000  1934         True
# 167             False             True   10100  1934         True
# 168              True            False   10101  1934         True
# 204             False            False   10000  1959         True
# 205             False            False   10100  1959         True
# 210             False            False   10100  1961         True
# 220             False            False   10100  1971         True

# %%
df['distorted'] = df['genres'].apply(if_elements_in_column_then_feature_is, list_of_elements=['ocr'])
df[
    df['distorted'] == True
   ]
# Out:
#                                               filename        date  \
# 255  1990.11.13_ельцин_выступление.стенограмма.ocr_...  1990.11.13
# 257  1991.07.10_ельцин_выступление.обращение к граж...  1991.07.10
# 265  1992.03.31_ельцин.другие.совет народных депута...  1992.03.31
# 266  1992.03.31_ельцин_выступление.заключительное с...  1992.03.31
# 269  1993.04.25_ельцин_выступление.обращение к граж...  1993.04.25
# 271  1994.02.24_ельцин_выступление.послание.отчет.д...  1994.02.24
#
#                                         authors  \
# 255                                    [ельцин]
# 257                                    [ельцин]
# 265  [ельцин, другие, совет народных депутатов]
# 266                                    [ельцин]
# 269                                    [ельцин]
# 271                                    [ельцин]
#
#                                             genres  \
# 255                [выступление, стенограмма, ocr]
# 257  [выступление, обращение к гражданам, тв, ocr]
# 265                                 [договор, ocr]
# 266       [выступление, заключительное слово, ocr]
# 269  [выступление, обращение к гражданам, тв, ocr]
# 271    [выступление, послание, отчет, доклад, ocr]
#
#                                                  names  \
# 255              [на 2 сессии верховного совета рсфср]
# 257  [выступление перед телезрителями по итогам выб...
# 265                             [федеративный договор]
# 266            [при подписании федеративных договоров]
# 269  [выступление перед телезрителями с подведением...
# 271          [с посланием перед федеральным собранием]
#
#                                         topics  multiple_authors  \
# 255           [сессия верховного совета рсфср]             False
# 257                              [выборы 1996]             False
# 265                     [федеративный договор]              True
# 266                    [федеративные договоры]             False
# 269                          [референдум 1993]             False
# 271  [с посланием перед федеральным собранием]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 255               True            False                False
# 257               True            False                 True
# 265               True             True                False
# 266               True            False                False
# 269               True            False                 True
# 271               True            False                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted
# 255              True             True   01001  1990        False       True
# 257             False             True   01010  1991        False       True
# 265             False            False   11100  1992        False       True
# 266             False             True   01000  1992        False       True
# 269             False             True   01010  1993        False       True
# 271             False            False   01000  1994        False       True

# %%
df['full_pattern'] = df['multiple_authors'].astype(int).astype(str) \
+df['leader_in_authors'].astype(int).astype(str)\
+df['is_written_text'].astype(int).astype(str)\
+df['addressed_to_people'].astype(int).astype(str)\
+df['regular_occasion'].astype(int).astype(str)\
+df['has_major_topic'].astype(int).astype(str)\
+df['is_fragment'].astype(int).astype(str)
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted  \
# 0               False            False    0111  1894        False      False
# 1               False            False    0111  1896        False      False
# 2               False            False    0111  1899        False      False
# 3               False            False    0111  1903        False      False
# 4               False             True    0111  1904        False      False
# ..                ...              ...     ...   ...          ...        ...
# 357             False            False    0100  2024        False      False
# 358             False             True    0101  2024        False      False
# 359             False             True    0101  2024        False      False
# 360             False             True    0101  2024        False      False
# 361             False             True    0100  2024        False      False
#
#     full_pattern
# 0        0111000
# 1        0111000
# 2        0111000
# 3        0111000
# 4        0111010
# ..           ...
# 357      0100000
# 358      0101010
# 359      0101010
# 360      0101010
# 361      0100010
#
# [362 rows x 17 columns]

# %%
df['pattern'] = \
df['multiple_authors'].astype(int).astype(str) \
+df['leader_in_authors'].astype(int).astype(str)\
+df['is_written_text'].astype(int).astype(str)\
+df['addressed_to_people'].astype(int).astype(str)\
# +df['regular_occasion'].astype(int).astype(str)\
# +df['has_major_topic'].astype(int).astype(str)
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted  \
# 0               False            False    0111  1894        False      False
# 1               False            False    0111  1896        False      False
# 2               False            False    0111  1899        False      False
# 3               False            False    0111  1903        False      False
# 4               False             True    0111  1904        False      False
# ..                ...              ...     ...   ...          ...        ...
# 357             False            False    0100  2024        False      False
# 358             False             True    0101  2024        False      False
# 359             False             True    0101  2024        False      False
# 360             False             True    0101  2024        False      False
# 361             False             True    0100  2024        False      False
#
#     full_pattern
# 0        0111000
# 1        0111000
# 2        0111000
# 3        0111000
# 4        0111010
# ..           ...
# 357      0100000
# 358      0101010
# 359      0101010
# 360      0101010
# 361      0100010
#
# [362 rows x 17 columns]

# %%
df = df.drop(columns=['pattern_compressed'])

# %%
df['pattern_compressed'] = df['pattern']
df['pattern_compressed'] = df['pattern_compressed'].apply(lambda x: x[0]+'X'+x[2:] if x[0] == '1' else x)
df[
    df['pattern_compressed'].apply(lambda x: x[0] == '1')
 ]
# Out:
#                                               filename        date  \
# 14   1917.03.03_временное правительство_декларация....  1917.03.03
# 15   1917.03.03_временное правительство_телеграмма....  1917.03.03
# 16   1917.03.06_временное правительство_обращение к...  1917.03.06
# 17   1917.03.22_временное правительство_постановлен...  1917.03.22
# 18   1917.04.12_временное правительство_постановлен...  1917.04.12
# ..                                                 ...         ...
# 265  1992.03.31_ельцин.другие.совет народных депута...  1992.03.31
# 270  1993.12.25_конституционная комиссия 1 съезда н...  1993.12.25
# 273  1994.12.16_совет федерации_постановление_о пол...  1994.12.16
# 278  1996.08.31_представители федеральной власти.пр...  1996.08.31
# 340  2020.07.03_рабочая группа по подготовке предло...  2020.07.03
#
#                                                authors  \
# 14                           [временное правительство]
# 15                           [временное правительство]
# 16                           [временное правительство]
# 17                           [временное правительство]
# 18                           [временное правительство]
# ..                                                 ...
# 265         [ельцин, другие, совет народных депутатов]
# 270  [конституционная комиссия 1 съезда народных де...
# 273                                  [совет федерации]
# 278  [представители федеральной власти, представите...
# 340  [рабочая группа по подготовке предложений о вн...
#
#                                   genres  \
# 14   [декларация, обращение к гражданам]
# 15              [телеграмма, за границу]
# 16               [обращение к гражданам]
# 17               [постановление, власть]
# 18               [постановление, власть]
# ..                                   ...
# 265                       [договор, ocr]
# 270                        [конституция]
# 273                      [постановление]
# 278   [соглашение, совместное заявление]
# 340                        [конституция]
#
#                                                  names  \
# 14                    [декларация о составе и задачах]
# 15                                   [о взятии власти]
# 16                 [создание временного правительства]
# 17   [об отмене вероисповедных и национальных огран...
# 18                              [о собраниях и союзах]
# ..                                                 ...
# 265                             [федеративный договор]
# 270                                   [конституция рф]
# 273               [о положении в чеченской республики]
# 278                          [хасавюртские соглашения]
# 340      [конституция рф, поправки к конституции 2020]
#
#                                                 topics  multiple_authors  \
# 14                    [декларация о составе и задачах]              True
# 15                                   [о взятии власти]              True
# 16                 [создание временного правительства]              True
# 17   [об отмене вероисповедных и национальных огран...              True
# 18                              [о собраниях и союзах]              True
# ..                                                 ...               ...
# 265                             [федеративный договор]              True
# 270                                   [конституция рф]              True
# 273                                    [война в чечне]              True
# 278       [завершение первой чеченской, война в чечне]              True
# 340      [конституция рф, поправки к конституции 2020]              True
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 14               False             True                False
# 15               False             True                False
# 16               False             True                False
# 17               False             True                False
# 18               False             True                False
# ..                 ...              ...                  ...
# 265               True             True                False
# 270              False             True                False
# 273              False             True                False
# 278              False             True                False
# 340              False             True                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted  \
# 14              False            False    1010  1917        False      False
# 15              False            False    1010  1917        False      False
# 16              False            False    1010  1917        False      False
# 17              False            False    1010  1917        False      False
# 18              False            False    1010  1917        False      False
# ..                ...              ...     ...   ...          ...        ...
# 265             False            False    1110  1992        False       True
# 270             False            False    1010  1993        False      False
# 273             False             True    1010  1994        False      False
# 278             False             True    1010  1996        False      False
# 340             False            False    1010  2020        False      False
#
#     full_pattern pattern_compressed
# 14       1010000               1X10
# 15       1010000               1X10
# 16       1010000               1X10
# 17       1010000               1X10
# 18       1010000               1X10
# ..           ...                ...
# 265      1110000               1X10
# 270      1010000               1X10
# 273      1010010               1X10
# 278      1010010               1X10
# 340      1010000               1X10
#
# [178 rows x 18 columns]

# %%
df['filename'].iloc[0]
# Out:
# '1894.10.20_николай ii_манифест_о восшествии на престол'

# %%
import re

# %%
from spacy.lang.ru import Russian

# %%
nlp = Russian()

# %%
nlp.max_length = 1500000

# %%
import os.path
from pathlib import Path

# %%
def count_tokens(filename):
    real_filename = '../corpus/'+re.sub(r' ', '-', filename, flags=re.IGNORECASE)+'.txt'
    if Path(real_filename).is_file():
        with open(real_filename, 'r') as f:
            doc = nlp(f.read()) 
            return len([token.text for token in doc])
    else: 
        print(real_filename)

# %%
df['token_count'] = df['filename'].apply(count_tokens)
# Out:
# ../corpus/1922.12.27_ленин_статья_о-придании-законодательных-функций-госплану.txt
# ../corpus/1922.12.30_ленин_статья_к-вопросу-о-национальностях-или-об-автономизации.txt
# ../corpus/1922.12.31_ленин_статья_к-вопросу-о-национальностях-или-об-автономизации-продолжение-2.txt
# ../corpus/1922.12.31_ленин_статья_к-вопросу-о-национальностях-или-об-автономизации-продолжение.txt
# ../corpus/1923.01.06_ленин_статья_о-кооперации.txt
# ../corpus/1923.01.17_ленин_статья_о-нашей-революции_ответ-на-записки-суханова.txt
# ../corpus/1923.01.23_ленин_статья.предложение-съезду-партии_как-нам-реорганизовать-рабкрин.txt
# ../corpus/1923.03.02_ленин_статья_лучше-меньше-да-лучше.txt
# ../corpus/1945.05.09_сталин_выступление.обращение-к-народу_наше-дело-правое-мы-победили_вов.победа.9-мая.2-мировая-войн.txt
# ../corpus/1988.06.30_партконференция19_обсуждение_обсуждение-доклада-задачи-по-углублению-перестройки-copy.txt
# ../corpus/1988.07.01_партконференция19_обсуждение_обсуждение-резолюции-задачи-по-углублению-перестройки-copy-2.txt
# ../corpus/1988.07.01_партконференция19_резолюция_задачи-по-углублению-перестройки-copy-3.txt
# ../corpus/2001.04.03_путин_выступление.послание_послание-федеральному-собранию-copy.txt
# ../corpus/2006.03.01_путин_статья_группа-восьми-на-пути-к-саммиту-в-спб_международные-отношения-copy.txt
# ../corpus/2006.11.17_путин_статья_атэс-принципиальный-выбор-россии-в-азиатско-тихоокеанском-регионе_международные-отношения-copy.txt
# ../corpus/2009.11.13_медведев_статья_атэс-на-пути-к-стабильному-безопасному-и-процветающему-сообществу_международные-отношения-copy.txt

# %%
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted  \
# 0               False            False    0111  1894        False      False
# 1               False            False    0111  1896        False      False
# 2               False            False    0111  1899        False      False
# 3               False            False    0111  1903        False      False
# 4               False             True    0111  1904        False      False
# ..                ...              ...     ...   ...          ...        ...
# 357             False            False    0100  2024        False      False
# 358             False             True    0101  2024        False      False
# 359             False             True    0101  2024        False      False
# 360             False             True    0101  2024        False      False
# 361             False             True    0100  2024        False      False
#
#     full_pattern  token_count
# 0        0111000        478.0
# 1        0111000        202.0
# 2        0111000        455.0
# 3        0111000        679.0
# 4        0111010        399.0
# ..           ...          ...
# 357      0100000      15982.0
# 358      0101010        512.0
# 359      0101010        384.0
# 360      0101010        667.0
# 361      0100010        886.0
#
# [362 rows x 18 columns]

# %%
path = Path("/here/your/path/file.txt")
print(path.parent.absolute())
# Out:
# /here/your/path

# %%
directory = os.path.join(Path(os.getcwd()).parent.absolute(), 'corpus')
print(directory)
# Out:
# /Users/nikolay/HSE/thesis/corpus

# %%
type(os.listdir(directory))
# Out:
# list

# %%
filenames = sorted(os.listdir(directory))

# %%
from numpy import nan, isnan
import re

# %%
df['filename_raw'] = df['filename']

# %%
for i in range(len(filenames)):
    filename = filenames[i]
    df['filename_raw'].loc[i] = filename
# Out:
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# ...
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['filename_raw'].loc[i] = filename
# /var/folders/bs/37p3rgss433755h614xs_rym0000gn/T/ipykernel_797/1209988778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename_raw'].loc[i] = filename

# %%
df
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted  \
# 0               False            False    0111  1894        False      False
# 1               False            False    0111  1896        False      False
# 2               False            False    0111  1899        False      False
# 3               False            False    0111  1903        False      False
# 4               False             True    0111  1904        False      False
# ..                ...              ...     ...   ...          ...        ...
# 357             False            False    0100  2024        False      False
# 358             False             True    0101  2024        False      False
# 359             False             True    0101  2024        False      False
# 360             False             True    0101  2024        False      False
# 361             False             True    0100  2024        False      False
#
#     full_pattern  token_count  \
# 0        0111000        478.0
# 1        0111000        202.0
# 2        0111000        455.0
# 3        0111000        679.0
# 4        0111010        399.0
# ..           ...          ...
# 357      0100000      15982.0
# 358      0101010        512.0
# 359      0101010        384.0
# 360      0101010        667.0
# 361      0100010        886.0
#
#                                           filename_raw
# 0    1894.10.20_николай-ii_манифест_о-восшествии-на...
# 1       1896.01.01_николай-ii_манифест_коронование.txt
# 2    1899.02.03_николай-ii_манифест_законы-княжеств...
# 3    1903.02.26_николай-ii_манифест_усовершенствова...
# 4    1904.01.27_николай-ii_манифест_об-открытии-вое...
# ..                                                 ...
# 357  2024.02.29_путин_выступление.послание_послание...
# 358  2024.03.14_путин_выступление.обращение-к-гражд...
# 359  2024.03.21_путин_выступление.обращение-к-гражд...
# 360  2024.03.23_путин_выступление.обращение-к-гражд...
# 361  2024.05.07_путин_выступление_выступление-на-це...
#
# [362 rows x 19 columns]

# %%
def count_tokens(filename):
    real_filename = '../corpus/'+filename
    if Path(real_filename).is_file():
        with open(real_filename, 'r') as f:
            doc = nlp(f.read()) 
            return len([token.text for token in doc])
    else: 
        print(real_filename)

# %%
df['token_count'] = df['filename_raw'].apply(count_tokens)

# %%
df.groupby('year')['token_count'].mean().plot.line()
# Out:
# <Axes: xlabel='year'>

# %%
df.groupby('year')['token_count'].sum().plot.line()
# Out:
# <Axes: xlabel='year'>

# %%
top_5_patterns
# Out:
# ['10100', '01000', '01100', '01010', '01001']

# %%
count_by_top_5_patters_by_year = df[
    df['pattern'].isin(top_5_patterns)
].groupby(by=['year','pattern'])['token_count'].sum()
count_by_top_5_patters_by_year
# Out:
#                                               filename        date  \
# 0    1894.10.20_николай ii_манифест_о восшествии на...  1894.10.20
# 1           1896.01.01_николай ii_манифест_коронование  1896.01.01
# 2    1899.02.03_николай ii_манифест_законы княжеств...  1899.02.03
# 3    1903.02.26_николай ii_манифест_усовершенствова...  1903.02.26
# 4    1904.01.27_николай ii_манифест_об открытии вое...  1904.01.27
# ..                                                 ...         ...
# 357  2024.02.29_путин_выступление.послание_послание...  2024.02.29
# 358  2024.03.14_путин_выступление.обращение к гражд...  2024.03.14
# 359  2024.03.21_путин_выступление.обращение к гражд...  2024.03.21
# 360  2024.03.23_путин_выступление.обращение к гражд...  2024.03.23
# 361  2024.05.07_путин_выступление_выступление на це...  2024.05.07
#
#           authors                                    genres  \
# 0    [николай ii]                                [манифест]
# 1    [николай ii]                                [манифест]
# 2    [николай ii]                                [манифест]
# 3    [николай ii]                                [манифест]
# 4    [николай ii]                                [манифест]
# ..            ...                                       ...
# 357       [путин]                   [выступление, послание]
# 358       [путин]  [выступление, обращение к гражданам, тв]
# 359       [путин]  [выступление, обращение к гражданам, тв]
# 360       [путин]  [выступление, обращение к гражданам, тв]
# 361       [путин]                             [выступление]
#
#                                                  names  \
# 0                            [о восшествии на престол]
# 1                                        [коронование]
# 2                      [законы княжества финляндского]
# 3          [усовершенствование государственной власти]
# 4         [об открытии военных действий против японии]
# ..                                                 ...
# 357                   [послание федеральному собранию]
# 358                            [обращение к гражданам]
# 359                            [обращение к гражданам]
# 360                            [обращение к гражданам]
# 361  [выступление на церемонии вступления в должнос...
#
#                                           topics  multiple_authors  \
# 0                      [о восшествии на престол]             False
# 1                                  [коронование]             False
# 2                [законы княжества финляндского]             False
# 3    [усовершенствование государственной власти]             False
# 4                   [русско японская война 1904]             False
# ..                                           ...               ...
# 357             [послание федеральному собранию]             False
# 358                                [выборы 2024]             False
# 359                 [выборы 2024, итоги выборов]             False
# 360                           [теракт в крокусе]             False
# 361                                [инаугурация]             False
#
#      leader_in_authors  is_written_text  addressed_to_people  \
# 0                 True             True                 True
# 1                 True             True                 True
# 2                 True             True                 True
# 3                 True             True                 True
# 4                 True             True                 True
# ..                 ...              ...                  ...
# 357               True            False                False
# 358               True            False                 True
# 359               True            False                 True
# 360               True            False                 True
# 361               True            False                False
#
#      regular_occasion  has_major_topic pattern  year  is_fragment  distorted  \
# 0               False            False    0111  1894        False      False
# 1               False            False    0111  1896        False      False
# 2               False            False    0111  1899        False      False
# 3               False            False    0111  1903        False      False
# 4               False             True    0111  1904        False      False
# ..                ...              ...     ...   ...          ...        ...
# 357             False            False    0100  2024        False      False
# 358             False             True    0101  2024        False      False
# 359             False             True    0101  2024        False      False
# 360             False             True    0101  2024        False      False
# 361             False             True    0100  2024        False      False
#
#     full_pattern  token_count  \
# 0        0111000          478
# 1        0111000          202
# 2        0111000          455
# 3        0111000          679
# 4        0111010          399
# ..           ...          ...
# 357      0100000        15982
# 358      0101010          512
# 359      0101010          384
# 360      0101010          667
# 361      0100010          886
#
#                                           filename_raw
# 0    1894.10.20_николай-ii_манифест_о-восшествии-на...
# 1       1896.01.01_николай-ii_манифест_коронование.txt
# 2    1899.02.03_николай-ii_манифест_законы-княжеств...
# 3    1903.02.26_николай-ii_манифест_усовершенствова...
# 4    1904.01.27_николай-ii_манифест_об-открытии-вое...
# ..                                                 ...
# 357  2024.02.29_путин_выступление.послание_послание...
# 358  2024.03.14_путин_выступление.обращение-к-гражд...
# 359  2024.03.21_путин_выступление.обращение-к-гражд...
# 360  2024.03.23_путин_выступление.обращение-к-гражд...
# 361  2024.05.07_путин_выступление_выступление-на-це...
#
# [362 rows x 19 columns]

# %%
top_5_patterns = df.groupby(by=['pattern']).count().sort_values(by=['filename'], ascending=False)['filename'].index.to_list()[:5]
top_5_patterns
# Out:
# ['1010', '0100', '0110', '0101', '1110']

# %%
count_by_top_5_patters_by_year = pd.DataFrame(df[
    df['pattern'].isin(top_5_patterns)
].groupby(by=['year','pattern'])['token_count'].sum())
count_by_top_5_patters_by_year
# Out:
#               token_count
# year pattern
# 1904 0110             853
# 1917 0110             784
#      1010           10137
#      1110            3009
# 1918 0100            9065
# ...                   ...
# 2023 0100           13460
#      0101            1360
#      0110            1679
# 2024 0100           16868
#      0101            1563
#
# [135 rows x 1 columns]

# %%
count_by_top_5_patters_by_year = pd.DataFrame(df[
    df['pattern'].isin(top_5_patterns)
].groupby(by=['year','pattern'])['token_count'].sum())

grouped_by_year_by_pattern = count_by_top_5_patters_by_year
grouped_by_year_by_pattern.pivot_table(values="token_count",index="year",columns="pattern").fillna(0).plot()
# Out:
# <Axes: xlabel='year'>

# %%
grouped_by_year_by_pattern.pivot_table(values="token_count",index="year",columns="pattern").fillna(0).mean()
# Out:
# pattern
# 0100    11123.561644
# 0101      763.123288
# 0110      883.109589
# 1010     4632.246575
# 1110      280.369863
# dtype: float64
