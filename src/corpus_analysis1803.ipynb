# %%
import pandas as pd

# %%
df = pd.read_csv('../input_data/source.csv',sep=';')

# %%
df
# Out:
#                                    path          author  sex birthday  \
# 0               post1950/anecdota/abstr             NaN  NaN      NaN
# 1            post1950/anecdota/andropov             NaN  NaN      NaN
# 2                post1950/anecdota/angl             NaN  NaN      NaN
# 3               post1950/anecdota/aptek             NaN  NaN      NaN
# 4              post1950/anecdota/armija             NaN  NaN      NaN
# ...                                 ...             ...  ...      ...
# 129336  pre1950/xx-1/zoschenko/satira44   М. М. Зощенко  муж     1894
# 129337  pre1950/xx-1/zoschenko/satira45   М. М. Зощенко  муж     1894
# 129338  pre1950/xx-1/zoschenko/satira46   М. М. Зощенко  муж     1894
# 129339  pre1950/xx-1/zoschenko/satira47   М. М. Зощенко  муж     1894
# 129340       pre1950/xx-1/nikolev/thule  Андрей Николев  муж     1895
#
#                                           header    created          sphere  \
# ...

# %%
def keywords_in_value(x, keywords: list):
    for k in keywords:
        if k in str(x):
            return True 
    return False

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "В. И. Ленин"
    ]))
]
df1
# Out:
#                                                     path       author  sex  \
# 76855                          pre1950/xx-1/lenin/gosrev  В. И. Ленин  муж
# 76856  pre1950/xx-1/lenin/lenin_w_i-text_1917_aprelsk...  В. И. Ленин  муж
# 76857                        pre1950/xx-1/lenin/lenin101  В. И. Ленин  муж
# 76858                        pre1950/xx-1/lenin/lenin102  В. И. Ленин  муж
# 76859                        pre1950/xx-1/lenin/lenin103  В. И. Ленин  муж
# 76860                        pre1950/xx-1/lenin/lenin104  В. И. Ленин  муж
# 76861                        pre1950/xx-1/lenin/lenin105  В. И. Ленин  муж
# 76862                        pre1950/xx-1/lenin/lenin106  В. И. Ленин  муж
# 76863                        pre1950/xx-1/lenin/lenin107  В. И. Ленин  муж
# 76864                        pre1950/xx-1/lenin/lenin108  В. И. Ленин  муж
# 76865                        pre1950/xx-1/lenin/lenin109  В. И. Ленин  муж
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Николай II"
    ]))
]
df1
# Out:
#                                                      path      author  sex  \
# 63820                            pre1950/xix/doc/docs_x13  Николай II  муж
# 66803            pre1950/xix/oldgazette/russlovo/russlo11  Николай II  муж
# 69709                        pre1950/xix/xronos-19/xron18  Николай II  муж
# 74980                 pre1950/xx-1/dok1900-1910s/duma1905  Николай II  муж
# 74981                 pre1950/xx-1/dok1900-1910s/duma1906  Николай II  NaN
# ...                                                   ...         ...  ...
# 123217  pre1950/xx-1/oldgazette/starosti/1916_07-12/st...  Николай II  муж
# 123521  pre1950/xx-1/oldgazette/starosti/1917_01-04/st...  Николай II  муж
# 123799  pre1950/xx-1/oldgazette/starosti/1917_01-04/st...  Николай II  муж
# 124140  pre1950/xx-1/oldgazette/starosti/1917_01-04/st...  Николай II  муж
# 124315  pre1950/xx-1/oldgazette/starosti/1917_01-04/st...  Николай II  муж
#
# ...

# %%
df[
    df['header'].apply(lambda x: keywords_in_value(x, [
        "РКП"
    ]))
]
# Out:
#                                                      path             author  \
# 73003          pre1950/xx-1/broshures/kom_univer/univer03         К. Шелабин
# 76911                  pre1950/xx-1/litmanifesty/litman27       коллективный
# 80158   pre1950/xx-1/oldgazette/k_hudojestv/k_hudojest...  Николай Насимович
# 126813                   pre1950/xx-1/pisma/metallist1920          А. Власов
#
#         sex birthday                                             header  \
# 73003   муж      NaN  История РКП. Лекция восьмая. Первый этап больш...
# 76911   NaN      NaN  Докладная записка, поданная группой «Перевал» ...
# 80158   NaN     1876          Литература. К художественной политике РКП
# 126813  муж      NaN          Неопубликованное открытое письмо в ЦК РКП
#
#        created                             sphere genre_fi             type  \
# 73003     1925  учебно-научная | нехудожественная      NaN           лекция
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "И. В. Сталин"
    ]))
]
df1
# Out:
#                                                      path        author  sex  \
# 75005               pre1950/xx-1/dok1941-45/stalin_vov_01  И. В. Сталин  муж
# 75006               pre1950/xx-1/dok1941-45/stalin_vov_02  И. В. Сталин  муж
# 75007               pre1950/xx-1/dok1941-45/stalin_vov_03  И. В. Сталин  муж
# 75008               pre1950/xx-1/dok1941-45/stalin_vov_04  И. В. Сталин  муж
# 75009               pre1950/xx-1/dok1941-45/stalin_vov_05  И. В. Сталин  муж
# 75010               pre1950/xx-1/dok1941-45/stalin_vov_06  И. В. Сталин  муж
# 75011               pre1950/xx-1/dok1941-45/stalin_vov_08  И. В. Сталин  муж
# 75012               pre1950/xx-1/dok1941-45/stalin_vov_09  И. В. Сталин  муж
# 75013               pre1950/xx-1/dok1941-45/stalin_vov_10  И. В. Сталин  муж
# 75014               pre1950/xx-1/dok1941-45/stalin_vov_11  И. В. Сталин  муж
# 75015               pre1950/xx-1/dok1941-45/stalin_vov_12  И. В. Сталин  муж
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Никита Хрущев",
        "Н. С. Хрущев"
    ]))
]
df1
# Out:
#                                                path         author  sex  \
# 45030   post1950/oldgazette/kp19610413/kp-196104_03   Н. С. Хрущев  муж
# 47428  post1950/oldgazette/ogonjok/1991_01/1991_017   Н. С. Хрущев  муж
# 47676  post1950/oldgazette/ogonjok/1991_16/ogonek03   Н. С. Хрущев  муж
# 53802          post1950/vagr/vagr4/xrushchev/vospom  Никита Хрущев  муж
# 53863            post1950/vagr/vagr6/kapitsa/kap_11   Н. С. Хрущев  муж
#
#       birthday                                             header    created  \
# 45030     1894  [Поздравление первому летчику-космонавту Ю. Га...       1961
# 47428     1894                Корейская война (из «Воспоминаний»)       1969
# 47676     1894               Японский синдром (из «Воспоминаний»)       1969
# 53802     1894                                       Воспоминания       1971
# 53863     1894               «Пусть простит меня академик Капица»  1970-1971
#
#                                 sphere genre_fi          type  \
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Л. И. Брежнев"
    ]))
]
df1
# Out:
#                                           path         author  sex birthday  \
# 22272    post1950/fiction_mem/brezhnev/mal_zem  Л. И. Брежнев  муж     1906
# 22273    post1950/fiction_mem/brezhnev/tselina  Л. И. Брежнев  муж     1906
# 22274    post1950/fiction_mem/brezhnev/vozrozh  Л. И. Брежнев  муж     1906
# 22275      post1950/fiction_mem/brezhnev/zhizn  Л. И. Брежнев  муж     1906
# 43225     post1950/nauka/Teh-mol/75_8/1975_805  Л. И. Брежнев  муж     1906
# 47869  post1950/oldgazette/pravda1970/pravda03  Л. И. Брежнев  муж      NaN
#
#                                                   header created  \
# 22272                                        Малая земля    1979
# 22273                                             Целина    1977
# 22274                                        Возрождение    1980
# 22275                          Жизнь по заводскому гудку    1980
# 43225  Приветствие товарища Л. И. Брежнева экипажам к...    1975
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "К. У. Черненко"
    ]))
]
df1
# Out:
# Empty DataFrame
# Columns: [path, author, sex, birthday, header, created, sphere, genre_fi, type, topic, chronotop, style, audience_age, audience_level, audience_size, source, publication, publisher, publ_year, medium, subcorpus, tagging, __num__]
# Index: []
#
# [0 rows x 23 columns]

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "М. С. Горбачев",
        "Горбачёв"
    ]))
]
df1
# Out:
#                                              path          author  sex  \
# 47855  post1950/oldgazette/pioner_pravda/p89_6303  М. С. Горбачев  муж
# 49403   post1950/oldgazette/trud/01011988/text1-1  М. С. Горбачев  муж
# 49434   post1950/oldgazette/trud/01011989/text1-1  М. С. Горбачев  муж
# 49557   post1950/oldgazette/trud/08111987/text1-3  М. С. Горбачев  муж
# 53505       post1950/vagr/vagr4/gorbachev/germany  М. С. Горбачев  муж
#
#       birthday                                    header created  \
# 47855     1931         Заявление товарища Горбачёва М. С    1989
# 49403     1931  Новогоднее обращение к советскому народу    1988
# 49434     1931  Новогоднее обращение к Советскому народу    1989
# 49557     1931       Выступление товарища Горбачева М. С    1987
# 53505     1931        Как это было. Объединение Германии    1999
#
#                                 sphere genre_fi          type  \
# 47855    публицистика|нехудожественная      NaN     заявление
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Ельцин",
    ]))
]
df1
# Out:
#                                                path        author  sex  \
# 47597  post1950/oldgazette/ogonjok/1991_12/1991_103  Ельцин Борис  муж
#
#       birthday                        header created  \
# 47597     1931  «Гражданской войны не будет»    1991
#
#                                 sphere genre_fi    type  \
# 47597  публицистика | нехудожественная      NaN  статья
#
#                                topic  ... audience_level  audience_size  \
# 47597  политика и общественная жизнь  ...      н-уровень  очень большая
#
#                                         source     publication publisher  \
# 47597  http://journal-club.ru/?q=image/tid/693  «Огонек». № 12  «Огонек»
#
#       publ_year  medium              subcorpus tagging __num__
# 47597      1991  журнал  ПК письменных текстов    none   47616
#
# [1 rows x 23 columns]

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Путин",
    ]))
]
df1
# Out:
#                                                    path               author  \
# 9201            post1950/archive/zhurn/dipl_vest/519112          В. В. Путин
# 9223          post1950/archive/zhurn/dipl_vest/51912701          В. В. Путин
# 9225          post1950/archive/zhurn/dipl_vest/51912801          В. В. Путин
# 9233          post1950/archive/zhurn/dipl_vest/51913201          В. В. Путин
# 9234          post1950/archive/zhurn/dipl_vest/51913202          В. В. Путин
# 9236          post1950/archive/zhurn/dipl_vest/51913301          В. В. Путин
# 9270          post1950/archive/zhurn/dipl_vest/51914602          В. В. Путин
# 9271          post1950/archive/zhurn/dipl_vest/51914603          В. В. Путин
# 9278          post1950/archive/zhurn/dipl_vest/51914805          В. В. Путин
# 9279          post1950/archive/zhurn/dipl_vest/51914806          В. В. Путин
# 9394          post1950/archive/zhurn/dipl_vest/51916201          В. В. Путин
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Д. А. Медведев",
    ]))
]
df1
# Out:
# Empty DataFrame
# Columns: [path, author, sex, birthday, header, created, sphere, genre_fi, type, topic, chronotop, style, audience_age, audience_level, audience_size, source, publication, publisher, publ_year, medium, subcorpus, tagging, __num__]
# Index: []
#
# [0 rows x 23 columns]

# %%
df
# Out:
#                                    path          author  sex birthday  \
# 0               post1950/anecdota/abstr             NaN  NaN      NaN
# 1            post1950/anecdota/andropov             NaN  NaN      NaN
# 2                post1950/anecdota/angl             NaN  NaN      NaN
# 3               post1950/anecdota/aptek             NaN  NaN      NaN
# 4              post1950/anecdota/armija             NaN  NaN      NaN
# ...                                 ...             ...  ...      ...
# 129336  pre1950/xx-1/zoschenko/satira44   М. М. Зощенко  муж     1894
# 129337  pre1950/xx-1/zoschenko/satira45   М. М. Зощенко  муж     1894
# 129338  pre1950/xx-1/zoschenko/satira46   М. М. Зощенко  муж     1894
# 129339  pre1950/xx-1/zoschenko/satira47   М. М. Зощенко  муж     1894
# 129340       pre1950/xx-1/nikolev/thule  Андрей Николев  муж     1895
#
#                                           header    created          sphere  \
# ...

# %%
df.groupby(by='author').size().sort_values(ascending=False).index.to_list()
# Out:
# ['неизвестный',
#  'обобщенный',
#  'коллективный',
#  'А. С. Пушкин',
#  'митрополит Антоний (Блум)',
#  'А. Артамонов',
#  'А. П. Чехов',
#  'Ф. Ф. Ушаков',
#  'Д. И. Фонвизин',
#  'архиепископ Платон (Левшин)',
#  'М. В. Ломоносов',
#  'В. Ф. Майстрах',
#  'А. С. Грин',
#  'М. Е. Салтыков-Щедрин',
#  'Н. Н. Муравьев-Амурский',
#  'К. И. Чуковский',
#  'В. М. Гаршин',
#  'В. Н. Татищев',
#  'В. В. Докучаев',
#  'И. А. Бунин',
#  'Василий Шукшин',
#  'М. О. Меньшиков',
#  'Д. И. Хармс',
#  'А. И. Куприн',
#  'В. Т. Шаламов',
#  'М. М. Зощенко',
#  'Н. А. Лейкин',
#  'Л. Н. Толстой',
#  'Максим Горький',
#  'Вл. А. Гиляровский',
#  'И. В. Киреевский',
#  'Елена Короп',
#  'А. С. Серафимович',
#  'А. Н. Будищев',
#  'А. О. Корнилович',
#  'Александр Волков',
#  'Максим Соколов',
#  'П. А. Столыпин',
#  'Мария Игнатова',
#  'Юрий Казаков',
#  'В. Г. Короленко',
#  'Н. Н. Пунин',
#  'Рюрик Ивнев',
#  'Ольга Губенко',
#  'М. М. Пришвин',
#  'Андрей Битов',
#  'П. Н. Лебедев',
# ...

# %%
df1 = df[
    df['author'].apply(lambda x: keywords_in_value(x, [
        "Николай II",
        "В. И. Ленин",
        "И. В. Сталин",
        "Н. С. Хрущев",
        "Никита Хрущев",
        "Л. И. Брежнев",
        "М. С. Горбачев",
        "Ельцин",
        "Путин",
    ]))
]
df1
# Out:
#                                              path        author  sex birthday  \
# 9201      post1950/archive/zhurn/dipl_vest/519112   В. В. Путин  муж     1952
# 9223    post1950/archive/zhurn/dipl_vest/51912701   В. В. Путин  муж     1952
# 9225    post1950/archive/zhurn/dipl_vest/51912801   В. В. Путин  муж     1952
# 9233    post1950/archive/zhurn/dipl_vest/51913201   В. В. Путин  муж     1952
# 9234    post1950/archive/zhurn/dipl_vest/51913202   В. В. Путин  муж     1952
# ...                                           ...           ...  ...      ...
# 128255              pre1950/xx-1/stalin/14_19_unf  И. В. Сталин  муж     1878
# 128257                  pre1950/xx-1/stalin/14_27  И. В. Сталин  муж     1878
# 128258                  pre1950/xx-1/stalin/14_39  И. В. Сталин  муж     1878
# 128259                   pre1950/xx-1/stalin/14_4  И. В. Сталин  муж     1878
# 128261                   pre1950/xx-1/stalin/mvja  И. В. Сталин  муж     1878
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 9201 to 128261
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   path            169 non-null    object
#  1   author          169 non-null    object
#  2   sex             168 non-null    object
#  3   birthday        165 non-null    object
#  4   header          169 non-null    object
#  5   created         169 non-null    object
#  6   sphere          169 non-null    object
#  7   genre_fi        0 non-null      object
#  8   type            169 non-null    object
#  9   topic           162 non-null    object
#  10  chronotop       7 non-null      object
#  11  style           169 non-null    object
#  12  audience_age    169 non-null    object
#  13  audience_level  169 non-null    object
#  14  audience_size   169 non-null    object
#  15  source          169 non-null    object
#  16  publication     160 non-null    object
# ...

# %%
df1.groupby(by='type').size()
# Out:
# type
# дневник, записные книжки     3
# доклад                       6
# заметка                      2
# записка                      1
# заявление                    4
# интервью                     3
# информационное сообщение     2
# манифест                    12
# мемуары                      9
# монография                   1
# обзор                        1
# обращение                   17
# объявление                   2
# письмо                       2
# письмо личное                1
# письмо открытое             12
# подпись                      2
# поздравление                 7
# пресс-конференция            7
# приветствие                  1
# приказ                      17
# речь                        26
# статья                      14
# тезисы                       1
# телеграмма                   1
# указ                        15
# dtype: int64

# %%
df1[
    df1['type'] == 'доклад'
]
# Out:
#                                            path         author  sex birthday  \
# 47869   post1950/oldgazette/pravda1970/pravda03  Л. И. Брежнев  муж      NaN
# 75006     pre1950/xx-1/dok1941-45/stalin_vov_02   И. В. Сталин  муж     1878
# 75008     pre1950/xx-1/dok1941-45/stalin_vov_04   И. В. Сталин  муж     1878
# 75009     pre1950/xx-1/dok1941-45/stalin_vov_05   И. В. Сталин  муж     1878
# 75010     pre1950/xx-1/dok1941-45/stalin_vov_06   И. В. Сталин  муж     1878
# 128257                pre1950/xx-1/stalin/14_27   И. В. Сталин  муж     1878
#
#                                                    header created  \
# 47869                       Дело Ленина живет и побеждает    1970
# 75006   Доклад на торжественном заседании Московского ...    1941
# 75008   Доклад на торжественном заседании Московского ...    1942
# 75009   Доклад на торжественном заседании Московского ...    1943
# 75010   Доклад на торжественном заседании Московского ...    1944
# ...
